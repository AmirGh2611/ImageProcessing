# %% [markdown]
# ## Libraries

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Reading images

# %%
img1 = cv2.imread("Data/FerrisWheel.jpg")
img2 = cv2.imread("Data/FlyEye.jpg")
img3 = cv2.imread("Data/Grid.jpg")

# %% [markdown]
# ## Q0

# %%
plt.figure(figsize = (10, 7))
plt.subplot(131);plt.imshow(img1[...,::-1]);plt.title("image 1")
plt.subplot(132);plt.imshow(img2[...,::-1]);plt.title("image 2")
plt.subplot(133);plt.imshow(img3[...,::-1]);plt.title("image 3")
# Out:
# Text(0.5, 1.0, 'image 3')
